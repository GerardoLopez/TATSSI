# %%
import os
import xarray as xr

import matplotlib
matplotlib.use('nbagg')
import matplotlib.pyplot as plt

import gdal

# %%
DATADIR = "/home/glopez/Projects/TATSSI/TATSSI/input_output/data"
fname = "MOD13A2.A2018145.h09v07.006.VI_QA_Land_Water_Mask.tif"
fname = os.path.join(DATADIR, fname)

# Open dataset
qa = xr.open_rasterio(fname)

# %%
d = gdal.Open(fname)
b = d.GetRasterBand(1)
rat = b.GetDefaultRAT()
print(rat)
# Out:
# None

# %%
b.GetCategoryNames()

# %%
qa.plot()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="740">
