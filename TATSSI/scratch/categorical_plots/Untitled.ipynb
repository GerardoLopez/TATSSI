# %%
import os
import xarray as xr

import matplotlib
matplotlib.use('nbagg')
import matplotlib.pyplot as plt

import gdal

# %%
DATADIR = "/home/glopez/Projects/TATSSI/TATSSI/input_output/data"
fname = "MOD13A2.A2018145.h09v07.006.VI_QA_Land_Water_Mask.tif"
fname = os.path.join(DATADIR, fname)

# Open dataset
qa = xr.open_rasterio(fname)

# %%
ds = gdal.Open(fname)
rat = ds.GetRasterBand(1).GetDefaultRAT()

print(rat)
# Out:
# None

# %%
qa.
# Out:
# Help on method GetDefaultRAT in module osgeo.gdal:
#
# GetDefaultRAT(*args) method of osgeo.gdal.Band instance
#     GetDefaultRAT(Band self) -> RasterAttributeTable

# %%
b.GetCategoryNames()

# %%
qa.plot()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
