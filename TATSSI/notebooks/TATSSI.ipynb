# %% [markdown]
# # Tools for Analyzing Time Series of Satellite Imagery (TATSSI)

# %%
import sys
sys.path.append ("/home/glopez/Projects/TATSSI")

# Notebook helpers
from TATSSI.notebooks.helpers.helpers import Download

# %% [markdown]
# ## Download data
# TATSSI allows to dowload data products from the Land Processes Distributed Active Archive Center [LP DAAC](https://lpdaac.usgs.gov/) derived from different sensors such as:
#
# * Moderate Resolution Imaging Spectroradiometer [MODIS](https://lpdaac.usgs.gov/dataset_discovery/modis)
# * Visible Infrared Imaging Radiometer Suite [VIIRS](https://lpdaac.usgs.gov/dataset_discovery/viirs)
#
# Downloading products from the LP DAAC requires a NASA [EarthData](https://urs.earthdata.nasa.gov/) login, please, first regsiter as a user to get the login credentials.
#
# 1. Select your are of study, you have to select a valid tile from the standard MODIS/VIIRS sinusoidal grid. You can have an overview in [here](https://earth.app.goo.gl/KBwn3C).
# 2. Click on the ```Select product and dates``` button. Explore the available products, double click on the row of the one you want to download
# 3. Select a date range
# 4. Once you selected a product and dates to download, set the output directory. Click on the ```Select output directory``` to do it. You can create a new directory if needed.
# 5. Get your data! Just click on the ```Download product for selected dates```

# %%
# Get some data!
downloader = Download()
# Out:
# Button(description='Select tile, product and dates', layout=Layout(width='99.6%'), style=ButtonStyle(), toolti…
# Dropdown(description='Tiles:', options=('h00v07', 'h00v08', 'h00v09', 'h00v10', 'h01v06', 'h01v07', 'h01v08', …
# HTML(value='<b>MCD12Q1.051</b>', description='Product and version:', layout=Layout(width='100%'), placeholder=…
# DatePicker(value=datetime.datetime(2001, 1, 1, 0, 0), description='Select start date', style=DescriptionStyle(…
# DatePicker(value=datetime.datetime(2013, 12, 31, 0, 0), description='Select end date', style=DescriptionStyle(…
# Button(description='Select output directory', layout=Layout(width='99.6%'), style=ButtonStyle(), tooltip='Sele…
# HTML(value='<b>/home/glopez/Projects/TATSSI/data/MOD13A2.006</b>', description='Output directory:', layout=Lay…
# Button(description='Download product for selected dates', layout=Layout(width='99.6%'), style=ButtonStyle(), t…
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/Projects/TATSSI/TATSSI/notebooks/helpers/helpers.py in __on_download_button_clicked(self, b)
#     199         Launch the donwloader for user's selection of product and dates
#     200         """
# --> 201         get_modis_data(username, password, platform, product, tiles,
#     202                    output_dir, start_date,
#     203                    end_date=None, n_threads=5)
#
# NameError: name 'username' is not defined

# %%
from TATSSI.download.modis_downloader import get_modis_data

func = eval('get_modis_data')

# %%
help(func)
# Out:
# Help on function get_modis_data in module TATSSI.download.modis_downloader:
#
# get_modis_data(username, password, platform, product, tiles, output_dir, start_date, end_date=None, n_threads=5)
#     The main workhorse of MODIS downloading. This function will grab
#     products for a particular platform (MOLT, MOLA or MOTA). The products
#     are specified by their MODIS code (e.g. MCD45A1.051 or MOD09GA.006).
#     You need to specify a tile (or a list of tiles), as well as a starting
#     and end date. If the end date is not specified, the current date will
#     be chosen. Additionally, you can specify the number of parallel threads
#     to use. And you also need to give an output directory to dump your files.
#
#     Parameters
#     -----------
#     usearname: str
#         The username that is required to download data from the MODIS archive.
#     password: str
#         The password required to download data from the MODIS archive.
#     platform: str
#         The platform, MOLT, MOLA or MOTA. This basically relates to the sensor
#         used (or if a combination of AQUA & TERRA is used)
#     product: str
#         The MODIS product. The product name should be in MODIS format
#         (MOD09Q1.006, so product acronym dot collection)
#     tiles: str or iter
#         A string with a single tile (e.g. "h17v04") or a lits of such strings.
#     output_dir: str
#         The output directory
#     start_date: datetime
#         The starting date as a datetime object
#     end_date: datetime
#         The end date as a datetime object. If not specified, taken as today.
#     n_threads: int
#         The number of concurrent downloads to envisage. I haven't got a clue
#         as to what a good number would be here...

# %% [markdown]
# ## Process QA

# %% [markdown]
# ## Explore time series

# %% [markdown]
# ## Perform interpolation and or temporal aggregation
